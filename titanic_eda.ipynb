# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('D:\\1-Data Science\\11-EDA\Data\\titanic_train.csv')

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.isna()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
# the most null values are present in the age and cabin columns

data.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# from heatmap we can see that there are null vallues inside age and cabin column
# cbar is called color bar
# cbar = Flase used for hiding the color bar.


plt.figure(figsize = (8, 5))
sns.heatmap(data.isnull(), yticklabels=False, cbar = False)
# Out:
# <AxesSubplot:>

# %%
# Here we can see that the number of people who survived and dead from the total number of peoples 

sns.set_style('whitegrid')
sns.countplot(x = 'Survived', data=data, palette='hls')
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
# Number of people survived and dead based on their sex whether they were male or female
# from total prople died more were male (around 460-470)
# and the female died are less (around 80 - 90)

# from the people who survived more were females and less were male:
# survived males are around 100 - 110
# survived females are around 220 - 230 which is more than number of survived males.


sns.set_style('whitegrid')
sns.countplot(x = 'Survived', data=data, hue = 'Sex', palette = 'rainbow')
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
# we can see the count of people who died and survived based on the class in which they were travelling 
# people died more who were travelling in class 3.
# people survived less who were travelling in the class 3.
# the ratio of died and survived in class 2 are much balanced.
# people travelling from first class are more survived and less died compared to other two classes.


sns.set_style('whitegrid')
sns.countplot(x = 'Survived', hue = 'Pclass', data = data, palette = 'rainbow')
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
# here we plotted the distribution plot of age column from out dataset
# we can see there were more number of people whos age were between around 18 to 35. 


sns.displot(data['Age'].dropna(), kde = True, color='red', bins= 40)

# %%
data['Age'].hist(bins = 30, color = 'red')
# Out:
# <AxesSubplot:>

# %%
# this is the count of the people who were travelling allong with their spouse and siblings.


sns.set_style('whitegrid')
sns.countplot(x = 'SibSp', data = data, palette = 'rainbow')
plt.xlabel('Number of Spouse or Siblings')
plt.ylabel('Count of People')
plt.title('People travelling along with their Spous or Siblings or along with Both')
# Out:
# Text(0.5, 1.0, 'People travelling along with their Spous or Siblings or along with Both')

# %%
sns.distplot(data['Fare'], color = 'red')
# Out:
# <AxesSubplot:xlabel='Fare', ylabel='Density'>

# %%
data['Fare'].hist(bins = 30, color = 'red')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize = (8,6))
sns.boxplot(x = 'Pclass', y = 'Age', hue = 'Sex', data=data, palette='winter')
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Age'>

# %%
def imput_val(columns):
    Age = columns[0]
    Pclass = columns[1]

    if pd.isnull(Age):
        if Pclass == 1:
            return 37
        elif Pclass == 2:
            return 29
        else :
            return 23
        
    else :
        return Age

# %%
data['Age'] = data[['Age', 'Pclass']].apply(imput_val, axis = 1)

# %%
sns.heatmap(data.isnull(), yticklabels=False, cbar = False)
# Out:
# <AxesSubplot:>

# %%
data.drop('Cabin', axis = 'columns', inplace=True)

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
data.drop(['Name','Ticket'], axis = 'columns', inplace=True)

# %%
data
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0              1         0       3    male  22.0      1      0   7.2500
# 1              2         1       1  female  38.0      1      0  71.2833
# 2              3         1       3  female  26.0      0      0   7.9250
# 3              4         1       1  female  35.0      1      0  53.1000
# 4              5         0       3    male  35.0      0      0   8.0500
# ..           ...       ...     ...     ...   ...    ...    ...      ...
# 886          887         0       2    male  27.0      0      0  13.0000
# 887          888         1       1  female  19.0      0      0  30.0000
# 888          889         0       3  female  23.0      1      2  23.4500
# 889          890         1       1    male  26.0      0      0  30.0000
# 890          891         0       3    male  32.0      0      0   7.7500
#
#     Embarked
# 0          S
# 1          C
# 2          S
# 3          S
# 4          S
# ..       ...
# ...

# %%
data['Sex'] = pd.get_dummies(data['Sex'], drop_first=True)

# %%
embarked = pd.get_dummies(data['Embarked'], drop_first=True)

# %%
data
# Out:
#      PassengerId  Survived  Pclass    Sex   Age  SibSp  Parch     Fare  \
# 0              1         0       3   True  22.0      1      0   7.2500
# 1              2         1       1  False  38.0      1      0  71.2833
# 2              3         1       3  False  26.0      0      0   7.9250
# 3              4         1       1  False  35.0      1      0  53.1000
# 4              5         0       3   True  35.0      0      0   8.0500
# ..           ...       ...     ...    ...   ...    ...    ...      ...
# 886          887         0       2   True  27.0      0      0  13.0000
# 887          888         1       1  False  19.0      0      0  30.0000
# 888          889         0       3  False  23.0      1      2  23.4500
# 889          890         1       1   True  26.0      0      0  30.0000
# 890          891         0       3   True  32.0      0      0   7.7500
#
#     Embarked
# 0          S
# 1          C
# 2          S
# 3          S
# 4          S
# ..       ...
# ...
